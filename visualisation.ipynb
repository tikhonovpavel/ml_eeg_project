# %%
import numpy as np
import pyvista as pv
import matplotlib.pyplot as plt

# %%
example = np.load('C:/Users/andru/Desktop/models_out/test_2_pred.npz')
one_pred = []
for key in example.keys():
    one_pred.append(example[key][0,0])

# %%
for eeg in one_pred:
    # eeg = one_pred[1]
    print(eeg.shape)
    eeg[abs(eeg) < 0.002] = 0
    eeg = eeg/np.max(eeg)
    x,y,z = np.array(np.nonzero(eeg))
    values = eeg[np.nonzero(eeg)]
    # x,y,z = np.nonzero(dic)
    # values_d = dic[np.nonzero(dic)]
    # print(eeg)
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(x,y,z, c=values, alpha=1)
    ax.axis('off')
    plt.show()
# Out:
# (65, 65, 65)
# (65, 65, 65)
# (65, 65, 65)

# %%
electrodes = 'C:/Users/andru/Downloads/Telegram Desktop/Razorenova_128-eeg1005_ico4-dip_ico4-bem/Parcellation_2-lbl/2-lbl_dip-0.npy'

# eeg_data = eeg[:,-1]
# eeg_data = eeg_data[:, np.newaxis]
# z = np.zeros(eeg_data.shape)
# eeg_data = 255*np.concatenate((eeg_data, z, z), axis=1)

# eeg_mesh = pv.PolyData(eeg[:,:-1])
# eeg_mesh["colors"] = eeg_data.astype(np.uint8)

# pl = pv.Plotter()
# pl.add_mesh(eeg_mesh, scalars="colors", rgb=True)
# pl.show()

# to check the output


electrodes = 'C:/Users/andru/Downloads/Telegram Desktop/Razorenova_128-eeg1005_ico4-dip_ico4-bem/train/65_False_None_None_-20/input/2-lbl_dip-0.npy'
curr = 'C:/Users/andru/Downloads/Telegram Desktop/Razorenova_128-eeg1005_ico4-dip_ico4-bem/train/65_False_None_None_-20/output/2-lbl_eeg-0.npy'
eeg = np.load(electrodes)
dic = np.load(curr)
sprase = np.array(np.nonzero(eeg))
values = eeg[np.nonzero(eeg)]

x,y,z = np.nonzero(dic)
values_d = dic[np.nonzero(dic)]
# print(eeg)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(sprase[0], sprase[1], sprase[2], c=values, alpha=1)
ax.axis('off')
plt.show()

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x,y,z, c=values_d, alpha=1)
ax.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 20
#      18 electrodes = 'C:/Users/andru/Downloads/Telegram Desktop/Razorenova_128-eeg1005_ico4-dip_ico4-bem/train/65_False_None_None_-20/input/2-lbl_dip-0.npy'
#      19 curr = 'C:/Users/andru/Downloads/Telegram Desktop/Razorenova_128-eeg1005_ico4-dip_ico4-bem/train/65_False_None_None_-20/output/2-lbl_eeg-0.npy'
# ---> 20 eeg = np.load(electrodes)
#      21 dic = np.load(curr)
#      22 sprase = np.array(np.nonzero(eeg))
#
# File ~\AppData\Roaming\Python\Python39\site-packages\numpy\lib\npyio.py:405, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     403     own_fid = False
#     404 else:
# --> 405     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     406     own_fid = True
#     408 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/andru/Downloads/Telegram Desktop/Razorenova_128-eeg1005_ico4-dip_ico4-bem/train/65_False_None_None_-20/input/2-lbl_dip-0.npy'

# %%
a = ['a', 'b']
b = ['c', 'v']
d = {16: a, 12: b}
for key, item in dict.items():
    print(f'{key}: ', end='')
    print(*item)
# Out:
# 16: a b
# 12: c v
